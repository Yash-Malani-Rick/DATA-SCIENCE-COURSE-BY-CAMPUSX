# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Malani-Rick/DATA-SCIENCE-COURSE-BY-CAMPUSX/blob/master/SESSION07DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) OBJECT ORIENTED PROGRAMMING IN PYTHON : -

# %% [markdown]
# # Part - 1 : -

# %% [markdown]
# a) Classes In Python : -

# %% [markdown]
# In Python, a class is a blueprint for creating objects that encapsulate data (attributes) and functions (methods) together. It supports Object-Oriented Programming (OOP) concepts like encapsulation, inheritance, and polymorphism. A class is defined using the class keyword, and objects are created as instances of the class. The __init__() constructor initializes object attributes. Methods define the behavior of objects, while class variables store shared data. Classes promote code reusability, modularity, and organization in large programs.
#
#
#
# ```
# class Car:
#     def __init__(self, brand):
#         self.brand = brand
#
# ```

# %% [markdown]
# ---

# %% [markdown]
# * Types of Classes In Python : -
#
#   * In Python, classes can be categorized into several types based on their functionality:
#
#       1. Concrete Class: A normal class that can be instantiated to create objects.
#
#       2. Abstract Class: Defined using the abc module, it cannot be instantiated directly and may contain abstract methods to be implemented by subclasses.
#
#       3. Static Class: Contains only static methods using @staticmethod, does not depend on object state.
#
#       4. Singleton Class: Allows only one instance to exist throughout the program.
#
#       5. Data Class: Introduced with @dataclass decorator in Python 3.7+, used to store data efficiently without writing boilerplate code for initialization.

# %% [markdown]
# ---

# %% [markdown]
# b) Objects in Python : -
#
# In Python, an object is an instance of a class that represents a real-world entity with its own data (attributes) and behavior (methods). Every object is created using a class blueprint and can access class variables and functions. Objects store individual data values for attributes, making them unique. Multiple objects can be created from the same class, each having different properties.
#
# ```
# class Car:
#     def __init__(self, brand):
#         self.brand = brand
#
# car1 = Car("Toyota")   # Object 1
# car2 = Car("Honda")    # Object 2
# print(car1.brand)      # Output: Toyota
#
#
# ```

# %% [markdown]
# ---

# %% [markdown]
# c) Constructors In Python : -
#
# In Python, a constructor is a special method used to initialize an object’s attributes at the time of creation. It is defined using the __init__() method and is called automatically whenever an object is instantiated. The self parameter represents the current instance of the class. Constructors can be default constructors (no parameters, assigning fixed values) or parameterized constructors (accepting arguments to set attributes dynamically). They improve code readability, reduce redundancy, and ensure that every object starts in a valid state. Python does not have multiple constructors but can mimic them using default arguments or class methods.

# %% [markdown]
# ---

# %%
# Coding Examples Involving Classes and Objects : -

# Banking Application / ATM Machine :
class BankAccount:
    def __init__(self, account_number, account_holder, balance=0):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"✅ Deposited: ₹{amount}. New Balance: ₹{self.balance}")
        else:
            print("❌ Deposit amount must be positive!")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"✅ Withdrawn: ₹{amount}. Remaining Balance: ₹{self.balance}")
        else:
            print("❌ Insufficient funds or invalid amount!")

    # Method to check balance
    def check_balance(self):
        print(f"💰 Available Balance: ₹{self.balance}")

# -------------------------------
# ATM Simulation
# -------------------------------
def atm_menu(account):
    while True:
        print("\n=== ATM MENU ===")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            amount = float(input("Enter amount to deposit: "))
            account.deposit(amount)
        elif choice == '2':
            amount = float(input("Enter amount to withdraw: "))
            account.withdraw(amount)
        elif choice == '3':
            account.check_balance()
        elif choice == '4':
            print("✅ Thank you for using our ATM!")
            break
        else:
            print("❌ Invalid option! Try again.")

# Creating an account object
user_account = BankAccount("12345678", "Yash Malani", 1000)

# Starting ATM simulation
atm_menu(user_account)
# Out:
# === ATM MENU ===
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 1
# Enter amount to deposit: 1234567
# ✅ Deposited: ₹1234567.0. New Balance: ₹1235567.0
#
# === ATM MENU ===
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 2
# Enter amount to withdraw: 12345
# ✅ Withdrawn: ₹12345.0. Remaining Balance: ₹1223222.0
#
# === ATM MENU ===
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 3
# 💰 Available Balance: ₹1223222.0
#
# === ATM MENU ===
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice: 4
# ✅ Thank you for using our ATM!

# %% [markdown]
# ---

# %% [markdown]
# Method vs Function : -
#
# 1️⃣ Function
# * A block of code that performs a specific task.
#
# * Defined using the def keyword.
#
# * Can exist independently and is not tied to a class or object.
#
# * Can be called directly using its name.
#
#
#
# 2️⃣ Method
#
# * A function that is defined inside a class.
#
# * It is associated with objects and can access or modify their attributes.
#
# * Requires the first parameter self to refer to the current object instance.

# %% [markdown]
# ---

# %%
# functions examples :
def greet():
    print("Hello!")
greet()
# Out:
# Hello!

# %%
# Method Examples :
class Person:
    def say_hello(self):
        print("Hello from a method!")
p = Person()
p.say_hello()
# Out:
# Hello from a method!

# %% [markdown]
# ---

# %% [markdown]
# Magic Methods In Python : -
#
# Magic Methods in Python (also called dunder methods) are special predefined methods that start and end with double underscores (__methodname__). They allow classes to define or customize the behavior of built-in operations like arithmetic, comparison, string representation, object creation, etc.
#
#
#
#
# ---
#
# Key Points : -
#
# * Automatically invoked in certain situations.
#
# * Used to overload operators and make objects behave like built-in types.
#
# * Examples include __init__, __str__, __len__, __add__, __eq__, etc.

# %% [markdown]
# ---

# %% [markdown]
# Common Magic Methods : -
#
# | Magic Method  | Purpose                                       |
# | ------------- | --------------------------------------------- |
# | `__init__`    | Constructor, initializes object attributes    |
# | `__str__`     | Returns a string representation of the object |
# | `__len__`     | Defines behavior of `len()`                   |
# | `__add__`     | Defines `+` operator behavior for objects     |
# | `__eq__`      | Defines equality (`==`) check                 |
# | `__getitem__` | Enables indexing (`obj[key]`)                 |
# | `__call__`    | Makes an object callable like a function      |
# | `__del__`     | Destructor, called before object deletion     |

# %% [markdown]
# ---

# %%
# Code Examples : -

class Book:
    def __init__(self, title, pages):
        self.title = title
        self.pages = pages

    def __str__(self):
        return f"Book: {self.title}"

    def __len__(self):
        return self.pages

b = Book("Python Basics", 250)
print(b)        # Book: Python Basics  (__str__)
print(len(b))   # 250                  (__len__)
# Out:
# Book: Python Basics
# 250

# %% [markdown]
# ---

# %% [markdown]
# Class Diagram : -
#
# A Class Diagram is a visual representation of a class and its relationships in Object-Oriented Programming (OOP). It is a part of Unified Modeling Language (UML) used to model the structure of a system by showing classes, attributes, methods, and their associations.

# %% [markdown]
# ---

# %% [markdown]
# Key Components of Class Diagrams : -
#
# * Class Name – The name of the class.
#
# * Attributes (Variables) – Properties or data stored in the class.
#
# * Methods (Functions) – Actions or behavior of the class.
#
# * Relationships:
#
#    * Association (normal connection between classes)
#
#    * Inheritance (arrow with a hollow triangle)
#
#    * Aggregation / Composition (diamond arrow)
#
#    * Dependency (dashed arrow)

# %% [markdown]
# Basic Syntax Representation : -
#
# -------------------------
# |      ClassName        |
# -------------------------
# | + attribute1: type    |
# | - attribute2: type    |
# -------------------------
# | + method1(): return   |
# | + method2(param): ret |
# -------------------------
#
# * `+` = Public
#
# * `-` = Private
#
# * `#` = Protected

# %% [markdown]
# ---

# %% [markdown]
# Use of Constructor in a Practical Sense : -
#
# Constructors in Python are practically used to **automatically initialize object attributes** when creating an instance of a class. They save time by eliminating the need for separate setup functions, ensure objects start in a valid state, and allow dynamic data assignment, making code more organized, reusable, and easier to maintain.

# %% [markdown]
# ---

# %% [markdown]
# Concept of `-self` : -
#
# In Python, self is a reference to the current instance of the class. It allows access to the attributes and methods of the specific object being created or used. It must be the first parameter in every instance method of a class, though the name can be changed (conventionally self is used).
#
# Key Points : -
#
# * Refers to the current object on which the method is being called.
#
# * Used to set or access instance variables and methods.
#
# * Automatically passed to methods when called using an object.

# %%
# Code Example :

class Car:
    def __init__(self, brand):
        self.brand = brand   # 'self' refers to the current object

    def show(self):
        print("Car Brand:", self.brand)

car1 = Car("Toyota")
car1.show()  # Output: Car Brand: Toyota
# Out:
# Car Brand: Toyota

# %% [markdown]
# ---

# %%
# Code to make a fraction class : -

from math import gcd

class Fraction:
    # Constructor
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator
        self.simplify()

    # Method to simplify the fraction
    def simplify(self):
        common = gcd(self.numerator, self.denominator)
        self.numerator //= common
        self.denominator //= common

    # Method to display fraction
    def display(self):
        print(f"{self.numerator}/{self.denominator}")

    # Operator Overloading for Addition
    def __add__(self, other):
        num = self.numerator * other.denominator + other.numerator * self.denominator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    # Operator Overloading for Subtraction
    def __sub__(self, other):
        num = self.numerator * other.denominator - other.numerator * self.denominator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    # Operator Overloading for Multiplication
    def __mul__(self, other):
        num = self.numerator * other.numerator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    # Operator Overloading for Division
    def __truediv__(self, other):
        num = self.numerator * other.denominator
        den = self.denominator * other.numerator
        return Fraction(num, den)

# ----------------------------
# Testing Fraction Class
f1 = Fraction(2, 4)
f2 = Fraction(3, 5)

print("Fraction 1:", end=" "); f1.display()
print("Fraction 2:", end=" "); f2.display()

result = f1 + f2
print("Addition Result:", end=" "); result.display()

result = f1 - f2
print("Subtraction Result:", end=" "); result.display()

result = f1 * f2
print("Multiplication Result:", end=" "); result.display()

result = f1 / f2
print("Division Result:", end=" "); result.display()
# Out:
# Fraction 1: 1/2
# Fraction 2: 3/5
# Addition Result: 11/10
# Subtraction Result: -1/10
# Multiplication Result: 3/10
# Division Result: 5/6

# %% [markdown]
# ---

# %% [markdown]
# # Part - 2 : -

# %% [markdown]
# ---

# %% [markdown]
# How Objects access Attributes : -

# %% [markdown]
# In Python, objects access attributes using the dot (.) operator. Attributes are variables or properties that belong to an object (instance of a class). They are usually defined inside the class constructor (__init__) or directly within the class.
#
# Ways Objects Access Attributes : -
#
# 1️⃣ Accessing Instance Attributes
#
# * Attributes defined using self inside the class can be accessed by the object.

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

car1 = Car("Toyota", "Red")
print(car1.brand)   # Access attribute
print(car1.color)
# Out:
# Toyota
# Red

# %% [markdown]
# 2️⃣ Modifying Attributes
#
# * Objects can change attribute values directly using the dot operator.

# %%
car1.color = "Blue"
print(car1.color)   # Output: Blue
# Out:
# Blue

# %% [markdown]
# 3️⃣ Accessing Class Attributes
#
# * Attributes defined outside methods (shared by all objects) are accessed using object or class name.

# %%
class Student:
    school = "DPS"

s1 = Student()
print(s1.school)         # Access via object
print(Student.school)    # Access via class name
# Out:
# DPS
# DPS

# %% [markdown]
# 4️⃣ Using getattr() Function
#
# * Attributes can also be accessed dynamically using getattr().

# %%
print(getattr(car1, "brand"))  # Output: Toyota
# Out:
# Toyota

# %% [markdown]
# ---

# %% [markdown]
# Attribute creation from outside of the class : -
#
# In Python, attributes can be created dynamically from outside a class by assigning a value to a variable using the dot (.) operator on an object. Unlike some languages, Python allows adding attributes to objects even after they are created.

# %%
# Example : -

class Person:
    def __init__(self, name):
        self.name = name

# Creating object
p1 = Person("Yash")

# Creating a new attribute from outside the class
p1.age = 21

print(p1.name)   # Output: Yash
print(p1.age)    # Output: 21
# Out:
# Yash
# 21

# %% [markdown]
# Key Points:
#
# * Attributes created this way are specific to that particular object, not the class.
#
# * Other objects of the same class will not have this dynamically created attribute unless explicitly added.

# %%
p2 = Person("Aman")
# print(p2.age)  # ❌ Error: 'Person' object has no attribute 'age'

# %% [markdown]
# ---

# %% [markdown]
# Reference Variables : -
#
# In Python, a reference variable is a variable that points to the memory location of an object rather than storing the object’s value directly. Multiple reference variables can refer to the same object, meaning changes made through one reference affect all others pointing to that object.

# %% [markdown]
# Key Points about Reference Variables : -
#
# * Python variables store references, not the actual object data.
#
# * Assigning one variable to another does not copy the object, only the reference.
#
# * Useful for passing objects to functions without duplication.
#
# * Can lead to shared modifications if multiple variables point to the same mutable object.

# %%
list1 = [10, 20, 30]
list2 = list1  # list2 is a reference to list1

list2.append(40)
print(list1)  # Output: [10, 20, 30, 40] (affected by list2)
# Out:
# [10, 20, 30, 40]

# %%
# Checking References (id() function) :

print(id(list1))
print(id(list2))  # Both have the same memory reference
# Out:
# 132039215667392
# 132039215667392

# %% [markdown]
# ---

# %% [markdown]
# Pass By Reference : -
#
# In Python, pass by reference means when an object reference (not the actual value) is passed to a function, allowing the function to modify the original object. Since Python variables store references, mutable objects (like lists, dictionaries, sets) exhibit pass-by-reference behavior.

# %% [markdown]
# Key Points : -
#
# * Function receives a reference to the object, not a copy.
#
# * Changes inside the function affect the original object (if mutable).
#
# * Immutable objects (like integers, strings, tuples) behave differently since they cannot be altered in place.

# %%
# Code Example : -

def modify_list(lst):
    lst.append(100)
    print("Inside function:", lst)

my_list = [1, 2, 3]
modify_list(my_list)
print("Outside function:", my_list)
# Out:
# Inside function: [1, 2, 3, 100]
# Outside function: [1, 2, 3, 100]

# %% [markdown]
# ✅ Both lists changed since the function worked on the same reference.

# %% [markdown]
# ---

# %% [markdown]
# Mutability of Object : -
#
# In Python, mutability of an object refers to whether the value of the object can be changed after it is created.

# %% [markdown]
# 1️⃣ Mutable Objects : -
#
# * Their content can be modified without changing their memory reference.
#
# * Examples: list, dictionary, set, bytearray.

# %%
# Code Example : -

my_list = [1, 2, 3]
print(id(my_list))     # Memory reference
my_list.append(4)      # Modify content
print(my_list)         # [1, 2, 3, 4]
print(id(my_list))     # Same reference
# Out:
# 132039215663872
# [1, 2, 3, 4]
# 132039215663872

# %% [markdown]
# 2️⃣ Immutable Objects : -
#
# * Their value cannot be changed once created; any modification creates a new object in memory.
#
# * Examples: int, float, string, tuple, frozenset.

# %%
# Code Example : -

x = "Hello"
print(id(x))
x = x + " World"       # Creates a new object
print(x)               # Hello World
print(id(x))           # Different memory reference
# Out:
# 132039215681520
# Hello World
# 132039215686512

# %% [markdown]
# ✅ Key Points : -
#
# * Mutability affects pass-by-reference behavior in functions.
#
# * Mutable objects can lead to unexpected side effects if shared across references.
#
# * Use immutable objects when data should not change for safety and reliability.

# %% [markdown]
# ---

# %% [markdown]
# Encapsulation : -
#
# Encapsulation is one of the four pillars of Object-Oriented Programming (OOP). It is the concept of wrapping data (attributes) and methods (functions) into a single unit (class) and restricting direct access to some components of an object to protect its data integrity.
#
# In Python, encapsulation is implemented using:
#
# * Public Members: Accessible from anywhere.
#
# * Protected Members: Marked with _ (single underscore); should not be accessed directly outside the class (convention).
#
# * Private Members: Marked with __ (double underscore); cannot be accessed directly outside the class.
#
# This ensures data hiding, allowing controlled access to data using getter and setter methods.

# %%
# Code Example : -

class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder   # Public attribute
        self._account_type = "Savings"         # Protected attribute
        self.__balance = balance               # Private attribute

    # Public method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"✅ Deposited ₹{amount}. New Balance: ₹{self.__balance}")
        else:
            print("❌ Invalid deposit amount!")

    # Public method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"✅ Withdrawn ₹{amount}. Remaining Balance: ₹{self.__balance}")
        else:
            print("❌ Insufficient balance or invalid amount!")

    # Getter method for private attribute
    def get_balance(self):
        return self.__balance

    # Setter method for private attribute
    def set_balance(self, amount):
        if amount >= 0:
            self.__balance = amount
        else:
            print("❌ Balance cannot be negative!")

# Creating object
acc = BankAccount("Yash Malani", 5000)

# Accessing public attribute
print("Account Holder:", acc.account_holder)

# Accessing protected attribute (not recommended directly)
print("Account Type:", acc._account_type)

# Accessing private attribute directly (will cause error)
# print(acc.__balance)  # ❌ AttributeError

# Correct way using getter
print("Current Balance:", acc.get_balance())

# Deposit and Withdraw
acc.deposit(1000)
acc.withdraw(3000)

# Modify balance using setter
acc.set_balance(8000)
print("Updated Balance:", acc.get_balance())
# Out:
# Account Holder: Yash Malani
# Account Type: Savings
# Current Balance: 5000
# ✅ Deposited ₹1000. New Balance: ₹6000
# ✅ Withdrawn ₹3000. Remaining Balance: ₹3000
# Updated Balance: 8000

# %% [markdown]
# ✅ Key Points of Encapsulation : -
#
# * Data Hiding: Prevents direct modification of sensitive attributes.
#
# * Controlled Access: Getter and setter methods ensure safe data manipulation.
#
# * Improved Security: Protects object’s state from accidental or unauthorized changes.
#
# * Reusability: Encapsulation makes classes more modular and reusable.

# %% [markdown]
# ---

# %% [markdown]
# Static Variables : -
#
# In Python, static variables (also known as class variables) are shared by all objects of a class. They are declared inside the class but outside all methods, meaning they belong to the class itself rather than any specific object. Any change made to a static variable affects all instances of that class.

# %% [markdown]
# 📌 Key Points : -
#
# * Declared directly under the class definition (not inside __init__).
#
# * Shared among all objects of the class.
#
# * Accessed using either the class name or the object reference.
#
# * Useful for storing data common to all objects, such as a counter or organization name.

# %%
# Code Example : -

class Student:
    school_name = "DPS"   # Static/Class variable

    def __init__(self, name, roll):
        self.name = name          # Instance variable
        self.roll = roll

# Creating objects
s1 = Student("Yash", 101)
s2 = Student("Aman", 102)

# Accessing static variable
print(s1.school_name)      # DPS
print(s2.school_name)      # DPS
print(Student.school_name) # DPS

# Changing static variable using class name
Student.school_name = "Delhi Public School"

print(s1.school_name)  # Delhi Public School
print(s2.school_name)  # Delhi Public School
# Out:
# DPS
# DPS
# DPS
# Delhi Public School
# Delhi Public School

# %% [markdown]
# Key Differences from Instances Variables : -
#
# | Feature     | Static Variable (Class Variable) | Instance Variable        |
# | ----------- | -------------------------------- | ------------------------ |
# | Scope       | Shared by all objects            | Unique to each object    |
# | Declaration | Inside class but outside methods | Inside `__init__` method |
# | Access      | Class name or object reference   | Object reference only    |

# %% [markdown]
# ---

# %% [markdown]
# # Part - 3 : -

# %% [markdown]
# Class Relationship : -
#
# In Object-Oriented Programming (OOP), Class Relationships describe how two or more classes are connected and interact with each other. These relationships help in designing structured, reusable, and scalable systems.

# %% [markdown]
# 1️⃣ Types of Class Relationships :
#
# 1. Association : -
#
#   * A basic relationship where one class uses another.
#
#   * Shows a "uses-a" or "has-a" connection.

# %%
# Code Example : -

class Driver:
    def __init__(self, name):
        self.name = name

class Car:
    def __init__(self, model, driver):
        self.model = model
        self.driver = driver

d = Driver("Yash")
c = Car("Toyota", d)   # Car is associated with Driver

# %% [markdown]
# 2. Aggregation : -
#
#     * A weaker form of association where one class contains another, but both can exist independently.

# %%
# Code Example : -

class Department:
    def __init__(self, name):
        self.name = name

class Employee:
    def __init__(self, name, dept):
        self.name = name
        self.dept = dept

dept = Department("HR")
emp = Employee("Aman", dept)  # Employee has a Department, but both can exist separately

# %% [markdown]
#  3. Composition : -
#
#     * A strong form of aggregation, where one class cannot exist without the other.

# %%
# Code Example : -

class Engine:
    def __init__(self, power):
        self.power = power

class Car:
    def __init__(self):
        self.engine = Engine("1500cc")  # Engine's lifecycle depends on Car

c = Car()  # Destroying Car destroys Engine

# %% [markdown]
# 4. Inheritance : -
#     * A "is-a" relationship, where a subclass inherits properties and methods of a parent class.

# %%
# Code Example : -

class Animal:
    def eat(self):
        print("This animal eats food")

class Dog(Animal):   # Dog is an Animal
    def bark(self):
        print("Dog barks")

# %% [markdown]
# 5. Dependency : -
#     * A temporary relationship, where one class depends on another to perform a task.

# %%
# Code Example : -

class Printer:
    def print_doc(self, document):
        print("Printing:", document)

class User:
    def use_printer(self):
        p = Printer()
        p.print_doc("Report")  # User depends on Printer temporarily

# %% [markdown]
# Summary : -
#
#
# | Relationship | Meaning           | Lifespan Dependency    |
# | ------------ | ----------------- | ---------------------- |
# | Association  | Uses/Has-a        | Independent            |
# | Aggregation  | Has-a (container) | Independent            |
# | Composition  | Has-a (strong)    | Dependent              |
# | Inheritance  | Is-a              | Parent-child hierarchy |
# | Dependency   | Uses temporarily  | Independent            |

# %% [markdown]
# ---

# %% [markdown]
# Aggregation In OOP : -
#
# Aggregation is a type of association relationship in Object-Oriented Programming where one class (the whole) contains a reference to another class (the part). Both classes can exist independently, meaning that the "part" object can live on its own, even if the "whole" object is destroyed.
#
# It represents a "Has-A" relationship but with loose coupling compared to composition.

# %% [markdown]
# Key Characteristics : -
#
# * A class is part of another class, but can exist independently.
#
# * Both objects have separate lifecycles.
#
# * Shown in UML diagrams with a hollow diamond arrow.

# %%
# Code Example : -

class Department:
    def __init__(self, name):
        self.name = name

class Employee:
    def __init__(self, emp_name, department):
        self.emp_name = emp_name
        self.department = department   # Aggregation (Employee has a Department)

    def show_details(self):
        print(f"Employee: {self.emp_name}, Department: {self.department.name}")

# Creating department object
dept1 = Department("Human Resources")

# Creating employee object and associating with department
emp1 = Employee("Yash", dept1)

emp1.show_details()  # Output: Employee: Yash, Department: Human Resources

# Deleting employee object does not affect department
del emp1
print(dept1.name)    # Output: Human Resources
# Out:
# Employee: Yash, Department: Human Resources
# Human Resources

# %% [markdown]
# Key Differences : -
#
# | Feature    | Aggregation                    | Composition                           |
# | ---------- | ------------------------------ | ------------------------------------- |
# | Dependency | Weak (objects independent)     | Strong (part depends on whole)        |
# | Lifespan   | "Part" can outlive the "whole" | "Part" destroyed when "whole" is gone |
# | UML Symbol | Hollow diamond                 | Filled diamond                        |

# %% [markdown]
# ---

# %% [markdown]
# Aggregation Class Diagram : -
#
# An Aggregation Class Diagram is a type of UML (Unified Modeling Language) diagram that represents a "whole-part" relationship between two classes, where one class (the whole) contains or uses another class (the part), but both can exist independently.

# %% [markdown]
# Key Characteristics of Aggregation : -
#
# * Relationship Type: Represents a "Has-A" relationship (e.g., Employee has a Department).
#
# * Lifespan: The contained class (part) can exist without the container class (whole).
#
# * Coupling: Loosely coupled compared to composition.
#
# * UML Notation: Represented by a hollow diamond at the "whole" end, connected to the "part" class.
#
# * Multiplicity: Can indicate one-to-one or one-to-many relationships.

# %% [markdown]
# Example in Context : -
#
# * Classes: Employee and Department.
#
# * Relationship: An Employee is associated with a Department, but the Department can exist independently even if no employees are present.

# %% [markdown]
# Diagram Representation : -
#
#
#
# ```
# [Department] ◇───── [Employee]
#
# ```
#
# * ◇ (Hollow Diamond): Shows an aggregation relationship.
#
# * Department = Whole
#
# * Employee = Part

# %% [markdown]
# Conclusion : -
#
# Aggregation class diagrams help in designing modular systems, showing ownership without strong dependency, and improving code reusability and clarity in object-oriented programming.

# %% [markdown]
# ---

# %% [markdown]
# Inheritance : -
#
# Inheritance is one of the fundamental concepts of Object-Oriented Programming (OOP) that allows a class (child or derived class) to acquire properties and behaviors (attributes and methods) of another class (parent or base class).
#
# It promotes code reusability, modularity, and hierarchical relationships between classes.
# The derived class can also extend or override the behavior of the base class.

# %% [markdown]
# Key Points In Inheritance : -
#
# * Enables code reusability by avoiding duplicate code.
#
# * Provides a "is-a" relationship (e.g., A Dog is an Animal).
#
# * Allows method overriding in the child class.
#
# * Supports different types of inheritance:
#
#  * Single Inheritance (one parent → one child)
#
#  * Multiple Inheritance (multiple parents → one child)
#
#  * Multilevel Inheritance (parent → child → grandchild)
#
#  * Hierarchical Inheritance (one parent → multiple children)
#
#  * Hybrid Inheritance (combination of types)

# %%
# Example for Single Inheritance : -

# Base class (Parent)
class Animal:
    def __init__(self, name):
        self.name = name

    def eat(self):
        print(f"{self.name} is eating.")

# Derived class (Child)
class Dog(Animal):
    def bark(self):
        print(f"{self.name} is barking.")

# Creating object of child class
d = Dog("Tommy")
d.eat()    # Inherited from Animal
d.bark()   # Defined in Dog


# Example for Method Over-Riding : -

class Animal:
    def sound(self):
        print("Animals make sounds.")

class Cat(Animal):
    def sound(self):
        print("Cat meows.")  # Overriding parent method

obj = Cat()
obj.sound()
# Out:
# Tommy is eating.
# Tommy is barking.
# Cat meows.

# %% [markdown]
# Advantages of Inheritance : -
#
# * Promotes code reusability and organization.
#
# * Helps in creating a logical class hierarchy.
#
# * Supports polymorphism (one name, multiple behaviors).
#
# * Reduces redundancy and makes code more maintainable.

# %% [markdown]
# Inheritance Class Diagram : -
#
# An Inheritance Class Diagram in UML visually represents a parent-child relationship between classes where the child class inherits attributes and methods of the parent class. It defines an "is-a" relationship, promoting code reusability and hierarchy in OOP design. In UML, inheritance is shown using a solid line with a hollow triangle arrowhead, pointing from the child class to the parent class.
#
#
#
# ```
# [Animal] ◁──── [Dog]
#
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
# Code Example : -

class Animal:
    def eat(self): print("Eating...")
class Dog(Animal):
    def bark(self): print("Barking...")

# %% [markdown]
# ---

# %% [markdown]
# In Case of Inheritance what gets Inherited ??
#
# * Constructor
# * Non - Private Arrtibutes
# * Non Private Methods

# %% [markdown]
# ---

# %% [markdown]
# Super Keyword : -
#
# In Python, the super() keyword is used to access methods and attributes of a parent (base) class from its child (derived) class. It allows you to reuse and extend the functionality of the parent class without directly referencing its name, making the code more maintainable and flexible.

# %% [markdown]
# Key Points : -
#
# * Used to call parent class methods or constructors.
#
# * Avoids hardcoding the parent class name, making code adaptable in multi-level inheritance.
#
# * Commonly used to invoke the parent’s __init__() constructor or overridden methods.

# %% [markdown]
#  Example: Using super() to Call Parent Constructor

# %%
class Parent:
    def __init__(self, name):
        self.name = name
        print("Parent Constructor Called")

class Child(Parent):
    def __init__(self, name, age):
        super().__init__(name)   # Calls Parent class constructor
        self.age = age
        print("Child Constructor Called")

c = Child("Yash", 21)
print(c.name, c.age)
# Out:
# Parent Constructor Called
# Child Constructor Called
# Yash 21

# %% [markdown]
# Example: Using super() with Method Overriding

# %%
class Animal:
    def sound(self):
        print("Animals make sounds")

class Dog(Animal):
    def sound(self):
        super().sound()       # Call parent method
        print("Dogs bark")

d = Dog()
d.sound()
# Out:
# Animals make sounds
# Dogs bark

# %% [markdown]
# Benefits of super() : -
#
# * Promotes code reusability.
#
# * Supports multiple inheritance by using Method Resolution Order (MRO).
#
# * Improves readability and maintainability of class hierarchies.

# %% [markdown]
# ---

# %% [markdown]
# Super Constructor : -
#
# In Python, when a child class inherits from a parent class, it often needs to initialize attributes defined in the parent class. To achieve this, the super() constructor is used to call the parent class's __init__() method.
#
# This ensures that all the properties of the parent class are properly initialized in the child class, avoiding code duplication. It also maintains inheritance hierarchy in cases of multi-level or multiple inheritance.

# %% [markdown]
# Key Concepts : -
#
# * super().__init__() calls the parent class constructor.
#
# * Used in single and multiple inheritance scenarios.
#
# * Ensures constructor chaining, meaning parent attributes are initialized before child-specific attributes.
#
# * Prevents the need to hardcode parent class name, making the code more maintainable.

# %%
# Code Example : -

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print("Parent Constructor: Person initialized")

class Student(Person):
    def __init__(self, name, age, roll_no):
        super().__init__(name, age)  # Calling parent constructor
        self.roll_no = roll_no
        print("Child Constructor: Student initialized")

# Creating an object of Student
s1 = Student("Yash", 21, 101)
print("Name:", s1.name)
print("Age:", s1.age)
print("Roll No:", s1.roll_no)
# Out:
# Parent Constructor: Person initialized
# Child Constructor: Student initialized
# Name: Yash
# Age: 21
# Roll No: 101

# %% [markdown]
# How It Works :
#
# * The child class Student constructor first calls super().__init__(), which runs the parent (Person) constructor.
#
# * The parent class initializes name and age.
#
# * The child class then initializes its own attribute roll_no.
#
# * This ensures that all inherited attributes are available to the child class without rewriting parent code.

# %% [markdown]
# In short : The super constructor in Python allows constructor chaining, improving code reusability, scalability, and clarity in inheritance-based programs.

# %% [markdown]
# ---

# %% [markdown]
# Using Super Outside class : -
#
# In Python, the super() function is primarily designed to be used inside a class hierarchy, typically within instance methods or constructors, to call methods from the parent (superclass).
#
# However, using super() outside a class definition is not standard practice because it requires a proper context (like a method call on an instance) to determine the method resolution order (MRO).

# %% [markdown]
# Behaviour of super() outside a class : -
#
# 1. Normally Used Inside a Class :

# %%
class A:
    def show(self):
        print("Class A method")

class B(A):
    def show(self):
        super().show()   # ✅ Works correctly here
        print("Class B method")

obj = B()
obj.show()
# Out:
# Class A method
# Class B method

# %% [markdown]
# 2. Using super() outside a class :
#
#   * When used outside a class, you must explicitly provide arguments:
# super(CurrentClass, instance).method()

# %%
class Parent:
    def display(self):
        print("Parent display")

class Child(Parent):
    def display(self):
        print("Child display")

obj = Child()

# Using super outside the class
super(Child, obj).display()  # Explicitly specifying class and object
# Out:
# Parent display

# %% [markdown]
# ✅ Key Points : -
#
# * super() without arguments only works inside class methods, where Python can determine the current class and instance automatically.
#
# * When using super() outside a class, you must pass two arguments:
#
#   * The class name whose parent you want to access.
#
#   * The object (instance) through which you want to call the parent method.

# %% [markdown]
# ---

# %% [markdown]
# Can the super keyword access the data of the parent class ??
#
# Yes, the super() keyword can access the data (attributes and methods) of the parent class, but it can only do so through the parent class's methods or constructor, not directly.
#
# This is because super() is used to call the parent’s implementation, allowing inherited attributes to be initialized or accessed indirectly.

# %% [markdown]
# 1.  Accessing Parent Class Data via super() in Constructor : -

# %%
class Parent:
    def __init__(self, name):
        self.name = name

class Child(Parent):
    def __init__(self, name, age):
        super().__init__(name)     # Calls parent constructor
        self.age = age

obj = Child("Yash", 21)
print(obj.name)  # ✅ Data from Parent accessed via super()
# Out:
# Yash

# %% [markdown]
# 2.  Accessing Parent Class Methods (That Use Data) : -

# %%
class Parent:
    def __init__(self, value):
        self.value = value

    def show_data(self):
        print("Parent Data:", self.value)

class Child(Parent):
    def show_data(self):
        super().show_data()  # ✅ Calls parent method
        print("Child has extra data.")

obj = Child(100)
obj.show_data()
# Out:
# Parent Data: 100
# Child has extra data.

# %% [markdown]
# What super() CANNOT Do Directly : -
# * You cannot directly use super().attribute_name to access data unless that attribute is:
#
#   * Initialized in the parent’s constructor and
#
#   * Accessible through self or a parent method.

# %%
class A:
    def __init__(self):
        self.data = "Hello"

class B(A):
    def show(self):
        # print(super().data)  # ❌ AttributeError
        print(self.data)       # ✅ Works, since data is inherited

obj = B()
obj.show()
# Out:
# Hello

# %% [markdown]
# ✅ Conclusion:
#
# * super() can access parent class data indirectly by:
#
#   * Calling the parent constructor (__init__).
#
#   * Calling parent methods that return or display the data.
#
# * Direct attribute access via super().attribute is not supported.

# %% [markdown]
# ---

# %% [markdown]
# Inheritance Summary : -
#
# Inheritance is an Object-Oriented Programming (OOP) concept that allows a child class (subclass) to acquire attributes and methods from a parent class (superclass). It promotes code reusability, modularity, and extensibility.

# %% [markdown]
# 1️⃣ Key Features
#
# * Establishes an "is-a" relationship between classes.
#
# * Allows method overriding (child redefines parent method).
#
# * Supports super() to access parent class methods and constructor.
#
# * Reduces redundancy by reusing code.

# %% [markdown]
# 2️⃣ Types of Inheritance

# %% [markdown]
# | Type             | Description                                |
# | ---------------- | ------------------------------------------ |
# | **Single**       | One parent → One child                     |
# | **Multiple**     | One child inherits from multiple parents   |
# | **Multilevel**   | Parent → Child → Grandchild                |
# | **Hierarchical** | One parent → Multiple children             |
# | **Hybrid**       | Combination of different inheritance types |

# %% [markdown]
# 3️⃣ Example

# %%
class Parent:
    def show(self):
        print("This is the Parent class")

class Child(Parent):
    def display(self):
        print("This is the Child class")

obj = Child()
obj.show()
obj.display()
# Out:
# This is the Parent class
# This is the Child class

# %% [markdown]
# 4️⃣ Advantages
#
#  * Code Reusability – Avoids writing duplicate code.
#
#  * Extensibility – Easy to add new features in subclasses.
#
#  * Polymorphism – Same method name can behave differently.
#
#  * Better organization of class hierarchies.

# %% [markdown]
# ---

# %% [markdown]
# Types of Inheritance : -
#
#  In Python, inheritance has five types:
#
# 1️⃣ Single: One parent → one child.
#
# 2️⃣ Multiple: One child inherits from multiple parents.
#
# 3️⃣ Multilevel: A chain of inheritance (grandparent → parent → child).
#
# 4️⃣ Hierarchical: One parent has multiple children.
#
# 5️⃣ Hybrid: Combination of two or more inheritance types.

# %% [markdown]
# ---

# %% [markdown]
# SINGLE INHERITANCE :
#
# Single inheritance is an OOP concept where a child class derives properties and methods from a single parent class. It allows code reusability by enabling the subclass to access the parent’s attributes and behaviors while also adding its own specific features. This improves program modularity and avoids redundancy.

# %%
# Parent Class
class Animal:
    def eat(self):
        print("This animal eats food.")

# Child Class
class Dog(Animal):
    def bark(self):
        print("Dog barks loudly.")

# Object of Child Class
d = Dog()
d.eat()   # Inherited method
d.bark()  # Child's own method
# Out:
# This animal eats food.
# Dog barks loudly.

# %% [markdown]
# ---

# %% [markdown]
# MULTI - LEVEL INHERITANCE :
#
# Multilevel inheritance occurs when a class inherits from another class, which in turn inherits from a third class, forming a parent → child → grandchild hierarchy. It allows the lowest-level class to reuse properties and methods of all its ancestor classes, improving code reusability and structure.

# %%
class Grandparent:
    def feature1(self):
        print("Feature 1 from Grandparent")

class Parent(Grandparent):
    def feature2(self):
        print("Feature 2 from Parent")

class Child(Parent):
    def feature3(self):
        print("Feature 3 from Child")

# Creating object of Child class
obj = Child()
obj.feature1()  # Inherited from Grandparent
obj.feature2()  # Inherited from Parent
obj.feature3()  # Defined in Child
# Out:
# Feature 1 from Grandparent
# Feature 2 from Parent
# Feature 3 from Child

# %% [markdown]
# ---

# %% [markdown]
# HIERARCHICAL INHERITANCE :
#
# Hierarchical inheritance is a type of OOP inheritance where multiple child classes inherit from a single parent class. It allows code reusability, as the common attributes and methods are defined once in the parent class and shared by all child classes. Each child class can have its own unique properties and methods, in addition to the inherited ones. This structure is useful when different entities share common behavior but also require specialized functionalities.

# %%
# Parent Class
class Vehicle:
    def start(self):
        print("Vehicle is starting...")

# Child Class 1
class Car(Vehicle):
    def drive(self):
        print("Car is being driven.")

# Child Class 2
class Bike(Vehicle):
    def ride(self):
        print("Bike is being ridden.")

# Objects of child classes
c = Car()
b = Bike()

c.start()   # Inherited method
c.drive()   # Child's method

b.start()   # Inherited method
b.ride()    # Child's method
# Out:
# Vehicle is starting...
# Car is being driven.
# Vehicle is starting...
# Bike is being ridden.

# %% [markdown]
# ---

# %% [markdown]
# MULTIPLE  INHERITANCE :
#
# Multiple inheritance is an OOP concept where a child class inherits properties and methods from more than one parent class. It allows a class to combine functionalities of multiple base classes, promoting code reusability and flexibility. However, it may lead to ambiguity if multiple parent classes define methods with the same name. Python resolves such conflicts using the Method Resolution Order (MRO).

# %%
class Father:
    def skill1(self):
        print("Father's Skill: Driving")

class Mother:
    def skill2(self):
        print("Mother's Skill: Cooking")

class Child(Father, Mother):
    def skill3(self):
        print("Child's Skill: Painting")

# Creating object
c = Child()
c.skill1()
c.skill2()
c.skill3()
# Out:
# Father's Skill: Driving
# Mother's Skill: Cooking
# Child's Skill: Painting

# %% [markdown]
# ---

# %% [markdown]
# HYBRID INHERITANCE :
#
# Hybrid inheritance is a type of inheritance that combines two or more inheritance types (such as multiple, multilevel, or hierarchical inheritance) within the same program. It creates a more complex class relationship where a child class can inherit features from different parent classes or through multiple paths. This helps achieve code reusability and flexibility, but can sometimes lead to ambiguity (resolved using Method Resolution Order (MRO) in Python).

# %%
# Base Class
class Person:
    def info(self):
        print("This is a person.")

# Derived Class 1 (Single Inheritance)
class Student(Person):
    def study(self):
        print("This person is a student.")

# Derived Class 2 (Multiple Inheritance)
class Employee(Person):
    def work(self):
        print("This person is an employee.")

# Hybrid Class (inherits from both Student and Employee)
class WorkingStudent(Student, Employee):
    def details(self):
        print("This person studies and works.")

# Creating object
ws = WorkingStudent()
ws.info()     # Inherited from Person
ws.study()    # From Student
ws.work()     # From Employee
ws.details()  # From WorkingStudent
# Out:
# This is a person.
# This person is a student.
# This person is an employee.
# This person studies and works.

# %% [markdown]
# ---

# %% [markdown]
# Polymorphism : -
#
# Polymorphism is an Object-Oriented Programming (OOP) concept that allows one name (method or operator) to have multiple forms or behaviors based on the object or data type it is used with. It enables writing flexible and reusable code, where the same function or method can work on different objects.
#
# Python supports polymorphism in two main ways:
#
# * Compile-time Polymorphism: Achieved using method overloading or operator overloading.
#
# * Runtime Polymorphism: Achieved using method overriding in inheritance.

# %% [markdown]
# Types of Polymorphism : -
#
# 1.  Method Overriding (Runtime Polymorphism) :
#
#   * Occurs when a child class provides a new implementation of a method inherited from the parent class.

# %%
class Animal:
    def sound(self):
        print("Animals make different sounds")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")

# Polymorphic behavior
for obj in (Dog(), Cat()):
    obj.sound()
# Out:
# Dog barks
# Cat meows

# %% [markdown]
# 2. Operator Overloading (Compile-time Polymorphism) :
#
#   * Python allows operators to behave differently for different objects by defining special magic methods.

# %%
class Book:
    def __init__(self, pages):
        self.pages = pages

    # Overloading '+' operator
    def __add__(self, other):
        return self.pages + other.pages

b1 = Book(100)
b2 = Book(200)
print("Total pages:", b1 + b2)
# Out:
# Total pages: 300

# %% [markdown]
# ✅ Advantages of Polymorphism :
#
# * Increases code flexibility and reusability.
#
# * Allows single interface, multiple implementations.
#
# * Makes programs easier to scale and maintain.

# %% [markdown]
# ---

# %% [markdown]
# Method Overloading : -
#
# Method Overloading is a concept in Object-Oriented Programming where multiple methods share the same name but differ in the number or type of parameters.
#
# Unlike some languages (like Java or C++), Python does not support traditional method overloading.
# Instead, Python allows default arguments or variable-length arguments (*args, **kwargs) to achieve similar behavior, meaning a single method can handle different numbers of arguments dynamically.

# %% [markdown]
# Key Points :
#
# * Only the latest defined method with the same name is recognized by Python.
#
# * Overloading can be simulated using default or variable arguments.
#
# * Python supports operator overloading, but not true compile-time method overloading.

# %%
class MathOperations:
    def add(self, a=None, b=None, c=None):
        if a is not None and b is not None and c is not None:
            return a + b + c
        elif a is not None and b is not None:
            return a + b
        elif a is not None:
            return a
        else:
            return 0

obj = MathOperations()
print(obj.add(10))         # Output: 10
print(obj.add(10, 20))     # Output: 30
print(obj.add(10, 20, 30)) # Output: 60
# Out:
# 10
# 30
# 60

# %% [markdown]
# ✅ Summary :
#
# * Python does not allow multiple methods with the same name.
#
# * Method overloading is achieved using default arguments or *args.
#
# * Provides flexibility, allowing a single method to behave differently based on the number of arguments.

# %% [markdown]
# ---

# %% [markdown]
# # Part - 4 : -

# %% [markdown]
# Abstraction In Python : -
#
# Abstraction is an OOP concept that focuses on hiding implementation details and showing only the essential features of an object to the user. It allows programmers to interact with objects using a simplified interface, without worrying about their internal complexities. In Python, abstraction is typically achieved using abstract classes, interfaces (via abstract methods), and encapsulation techniques.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):  # Abstract Class
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car engine started with key ignition.")

class Bike(Vehicle):
    def start_engine(self):
        print("Bike engine started with self-start button.")

# Using abstraction
vehicles = [Car(), Bike()]
for v in vehicles:
    v.start_engine()
# Out:
# Car engine started with key ignition.
# Bike engine started with self-start button.

# %% [markdown]
# ---

# %% [markdown]
# Abstract Class In Python : -
#
# An abstract class is a class that cannot be instantiated directly and is meant to be a blueprint for other classes. It may have abstract methods (declared but not implemented), which must be implemented by its child classes. Abstract classes help enforce a common structure across all subclasses, ensuring they implement specific behaviors.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):  # Abstract class
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# obj = Shape()  # ❌ Cannot create object of abstract class
rect = Rectangle(10, 5)
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 50

# %% [markdown]
# ---

# %% [markdown]
# Key Differences : -
#
# | Feature       | Abstraction                     | Abstract Class                        |
# | ------------- | ------------------------------- | ------------------------------------- |
# | Definition    | Concept of hiding details       | A class that defines abstract methods |
# | Instantiation | Achieved via classes/interfaces | Cannot be instantiated directly       |
# | Purpose       | Simplifies user interaction     | Provides a blueprint for subclasses   |

# %% [markdown]
# ---
